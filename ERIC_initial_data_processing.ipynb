# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import openpyxl 
import os
# Load custom data processing tool
from data_processing import match_data

# %%
# Initialize the data cross referencing tool with a base file
base_model = pd.read_csv('base.csv')
base_model = base_model.sort_values(by='Local Authority name', key=lambda x: x.str.len())
base_model = base_model.reset_index(drop=True)
column=2

# Load and process data
# Format:
# model,column = load_data(path/filename,sheet_name,column_title,model,column)
model,column = match_data('Data/EnglandHomelessData_2020_21.xlsx','Eric_Sheet_2','Total owed a prevention or relief duty',base_model, column)
model,column = match_data('Data/EnglandHomelessData_2020_21.xlsx','Eric_Sheet_2','Threatened with homelessness within 56 days - Prevention duty owed',base_model, column)
model,column = match_data('Data/EnglandHomelessData_2020_21.xlsx','Eric_Sheet_2','Homeless - Relief duty owed4',model, column)
model,column = match_data('Data/EnglandHomelessData_2020_21.xlsx','Eric_Sheet_2','Number of households in area4 (000s)',model, column)
model,column = match_data('Data/EnglandHomelessData_2020_21.xlsx','need_duty_sheet','Total households with support needs',model, column)
model,column = match_data('Data/EnglandHomelessData_2020_21.xlsx','P1_processed','Total secured accommodation',model, column)
model,column = match_data('Data/EnglandHomelessData_2020_21.xlsx','P1_processed','Homeless (including intentionally homeless)',model, column)
model,column = match_data('Data/(Processed_for_catergoritcal_analysis)England Numbers of households on local authorities housing waiting lists.xlsx','Live_Table_600','Size_of_social_housing_waiting_list_2021',model, column)
model,column = match_data('Data/England_2020_April_to_September_Social_Housing_Lettings.xlsx','processed_table_1d','2021 Total Lettings',model, column)
model,column = match_data('Data/merge_all_data_processing.xlsx','ERIC_usage','Affordable Rent (Starts on Site)',model, column)
model,column = match_data('Data/merge_all_data_processing.xlsx','ERIC_usage','Social Rent (Starts on Site)',model, column)
model,column = match_data('Data/merge_all_data_processing.xlsx','ERIC_usage','Intermediate Rent (Starts on Site)',model, column)
model,column = match_data('Data/merge_all_data_processing.xlsx','ERIC_usage','Affordable Home Ownership (Starts on Site)',model, column)
model,column = match_data('Data/merge_all_data_processing.xlsx','ERIC_usage','Total Affordable (Starts on Site)',model, column)
model,column = match_data('Data/merge_all_data_processing.xlsx','ERIC_usage','Affordable Rent (Completions)',model, column)
model,column = match_data('Data/merge_all_data_processing.xlsx','ERIC_usage','Social Rent (Completions)',model, column)
model,column = match_data('Data/merge_all_data_processing.xlsx','ERIC_usage','Intermediate Rent (Completions)',model, column)
model,column = match_data('Data/merge_all_data_processing.xlsx','ERIC_usage','Affordable Home Ownership (Completions)',model, column)
model,column = match_data('Data/merge_all_data_processing.xlsx','ERIC_usage','Total Affordable (Completions)',model, column)
model,column = match_data('Data/merge_all_data_processing.xlsx','ERIC_usage','Total (Starts on Site)',model, column)
model,column = match_data('Data/merge_all_data_processing.xlsx','ERIC_usage','Total (Completions)',model, column)
model,column = match_data('Data/merge_all_data_processing.xlsx','ERIC_usage','Market (Starts on Site)',model, column)
model,column = match_data('Data/merge_all_data_processing.xlsx','ERIC_usage','Market  (Completions)',model, column)
model,column = match_data('Data/England_four_in_one_council_tax.xlsx','Sheet1','A_B_property_counts',model, column)
model,column = match_data('Data/England_four_in_one_council_tax.xlsx','Sheet1','C_D_property_counts',model, column)
model,column = match_data('Data/England_four_in_one_council_tax.xlsx','Sheet1','E_F_property_counts',model, column)
model,column = match_data('Data/England_four_in_one_council_tax.xlsx','Sheet1','G_H_property_counts',model, column)
model,column = match_data('Data/England_house_price_and_earning_statistics.xlsx','5a_new','median_houses_2020',model, column)
model,column = match_data('Data/England_house_price_and_earning_statistics.xlsx','5b_new','median_earning_2020',model, column)
model,column = match_data('Data/England_house_price_and_earning_statistics.xlsx','5c_new','ratio_by_medians_2020',model, column)
model,column = match_data('Data/England_house_price_and_earning_statistics.xlsx','6a_new','lower_quatile_houses_2020',model, column)
model,column = match_data('Data/England_house_price_and_earning_statistics.xlsx','6b_new','lower_quatile_earning_2020',model, column)
model,column = match_data('Data/England_house_price_and_earning_statistics.xlsx','6c_new','ratio_by_lower_quatile_2020',model, column)
print(model)
# Out:
#     Local Authority code       Local Authority name  \
# 0              E07000223                       Adur
# 1              E07000128                       Wyre
# 2              E07000089                       Hart
# 3              E07000030                       Eden
# 4              E08000002                       Bury
# ..                   ...                        ...
# 342            E07000146   King's Lynn West Norfolk
# 343            E06000022   Bath North East Somerset
# 344            E06000019   Herefordshire, County of
# 345            E06000011   East Riding of Yorkshire
# 346            E07000134  North West Leicestershire
#
#     Total owed a prevention or relief duty  \
# 0                                      139
# 1                                      507
# 2                                       99
# 3                                      121
# 4                                      731
# ..                                     ...
# ...

# %%
cwd = os.getcwd()
model.to_excel(os.path.join(cwd, "Data/all_in_one_Categorical_data.xlsx"),sheet_name = 'initial_analysis')

# %%
workbook = openpyxl.load_workbook('Data/all_in_one_Categorical_data_processed.xlsx')
categorical_data = pd.DataFrame(workbook['removed_unwanted_cells'].values)
categorical_data.columns = list(categorical_data.iloc[0])
categorical_data = categorical_data.drop(labels=0, axis=0)

# %%
categorical_data.columns
# Out:
# Index(['Local', 'Local Authority code', 'Local Authority name',
#        'Total owed a prevention or relief duty',
#        'Threatened with homelessness within 56 days - Prevention duty owed',
#        'Homeless - Relief duty owed4', 'Number of households in area4 (000s)',
#        'Total households with support needs', 'Total secured accommodation',
#        'Homeless (including intentionally homeless)',
#        'Size_of_social_housing_waiting_list_2021', '2021 Total Lettings',
#        'Affordable Rent (Starts on Site)', 'Social Rent (Starts on Site)',
#        'Intermediate Rent (Starts on Site)',
#        'Affordable Home Ownership (Starts on Site)',
#        'Total Affordable (Starts on Site)', 'Affordable Rent (Completions)',
#        'Social Rent (Completions)', 'Intermediate Rent (Completions)',
#        'Affordable Home Ownership (Completions)',
#        'Total Affordable (Completions)', 'Total (Starts on Site)',
#        'Total (Completions)', 'Market (Starts on Site)',
# ...
